# %%
import ktrain
from sklearn import metrics
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import classification_report

MAX_LEN = 10000
CATEGORIES_LIST = ['Arte e Design', 'Música e Áudio', 'Comunicação', 'Finanças', 'Entretenimento', 'Medicina', 'Comer e Beber', 'Reproduzir e Editar Videos', 'Mapas e Navegação', 'Social', 'Fotografia', 'Compras', 'Produtividade', 'Educação', 'Livros e Referência', 'Encontro', 'Turismo e Local', 'Ferramentas']
NAME_TERMINAL = "ep3"
print("start")
# Out:
# start

# %%
#Importando a biblioteca pandas e carregando as amostras
df_test = pd.read_pickle('./Amostras_Teste.pkl')
print(df_test.shape)
df_test = df_test.dropna()
print(df_test.shape)
print("importou as bibliotecas")
# Out:
# (1104646, 6)
# (1103844, 6)
# importou as bibliotecas

# %%
#Load predictor
p = ktrain.load_predictor('./bert-base-multilingual-cased_e3_apps.model')
print("carregou o modelo")
# Out:
# carregou o modelo

# %%
save_classification_context = []
save_classification_non_context = []
for this_category in CATEGORIES_LIST:
    df_aux = df_test[df_test['category']==this_category]
    if len(df_aux) > MAX_LEN:
        df_aux = df_aux.head(MAX_LEN)
    x_test_context = df_aux[['review', 'category']].values
    x_test_context = list(map(tuple, x_test_context))
    x_test_non_context = df_aux.review.values
    y_true = df_aux.label_feelings.values
    print(NAME_TERMINAL, this_category)
    #Predições com contexto
    y_pred_context = p.predict(x_test_context)
    print("Métricas com contexto:")
    save_classification_context.append(classification_report(y_true[0:len(y_pred_context)], y_pred_context))
    print(save_classification_context[-1])
    #Predições sem contexto
    y_pred_non_context = p.predict(x_test_non_context)
    print("Métricas sem contexto:")
    save_classification_non_context.append(classification_report(y_true[0:len(y_pred_non_context)], y_pred_non_context))
    print(save_classification_non_context[-1])
    
    print("Terminando processo de:", NAME_TERMINAL, this_category)
    print()
    
print("Encerrada a execução ----------------------------------------------------------")
# Out:
# ep3 Música e Áudio
# 313/313 [==============================] - 2382s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.90      0.92      5028
#     Positive       0.91      0.93      0.92      4972
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2347s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.91      0.92      5028
#     Positive       0.91      0.93      0.92      4972
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# Terminando processo de: ep3 Música e Áudio
#
# ep3 Comunicação
# 313/313 [==============================] - 2369s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.87      0.88      5048
#     Positive       0.87      0.89      0.88      4952
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
# 313/313 [==============================] - 2344s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.88      0.88      5048
#     Positive       0.87      0.88      0.88      4952
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
# Terminando processo de: ep3 Comunicação
#
# ep3 Finanças
# 313/313 [==============================] - 2340s 7s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.96      0.95      4932
#     Positive       0.96      0.93      0.95      5068
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# 313/313 [==============================] - 2356s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.97      0.95      4932
#     Positive       0.97      0.92      0.95      5068
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# Terminando processo de: ep3 Finanças
#
# ep3 Entretenimento
# 313/313 [==============================] - 2365s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.92      0.92      4968
#     Positive       0.92      0.92      0.92      5032
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2357s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.93      0.92      4968
#     Positive       0.93      0.91      0.92      5032
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# Terminando processo de: ep3 Entretenimento
#
# ep3 Medicina
# 313/313 [==============================] - 2358s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.97      0.96      4917
#     Positive       0.97      0.96      0.96      5083
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# 313/313 [==============================] - 2363s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.97      0.96      4917
#     Positive       0.97      0.96      0.96      5083
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# Terminando processo de: ep3 Medicina
#
# ep3 Comer e Beber
# 313/313 [==============================] - 2353s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.97      0.96      5010
#     Positive       0.97      0.96      0.96      4990
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# 313/313 [==============================] - 2355s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.97      0.96      5010
#     Positive       0.97      0.95      0.96      4990
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# Terminando processo de: ep3 Comer e Beber
#
# ep3 Corporativo
# 280/280 [==============================] - 2120s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.90      0.92      4482
#     Positive       0.90      0.94      0.92      4464
#
#     accuracy                           0.92      8946
#    macro avg       0.92      0.92      0.92      8946
# weighted avg       0.92      0.92      0.92      8946
#
# 280/280 [==============================] - 2082s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.88      0.91      4482
#     Positive       0.88      0.96      0.92      4464
#
#     accuracy                           0.92      8946
#    macro avg       0.92      0.92      0.92      8946
# weighted avg       0.92      0.92      0.92      8946
#
# Terminando processo de: ep3 Corporativo
#
# ep3 Estilo de Vida
# 263/263 [==============================] - 1950s 7s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.92      0.93      4198
#     Positive       0.92      0.93      0.93      4198
#
#     accuracy                           0.93      8396
#    macro avg       0.93      0.93      0.93      8396
# weighted avg       0.93      0.93      0.93      8396
#
# 263/263 [==============================] - 1967s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.90      0.92      4198
#     Positive       0.90      0.95      0.93      4198
#
#     accuracy                           0.92      8396
#    macro avg       0.92      0.92      0.92      8396
# weighted avg       0.92      0.92      0.92      8396
#
# Terminando processo de: ep3 Estilo de Vida
#
# ep3 Reproduzir e Editar Videos
# 313/313 [==============================] - 2373s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.86      0.88      5041
#     Positive       0.86      0.90      0.88      4959
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
# 313/313 [==============================] - 2345s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.87      0.87      5041
#     Positive       0.87      0.88      0.87      4959
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
#
# Terminando processo de: ep3 Reproduzir e Editar Videos
#
# ep3 Mapas e Navegação
# 313/313 [==============================] - 2362s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.94      0.93      5021
#     Positive       0.94      0.90      0.92      4979
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
# 313/313 [==============================] - 2347s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.96      0.92      5021
#     Positive       0.96      0.88      0.92      4979
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# Terminando processo de: ep3 Mapas e Navegação
#
# ep3 Social
# 313/313 [==============================] - 2361s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.90      0.89      4953
#     Positive       0.90      0.89      0.89      5047
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
#
# 313/313 [==============================] - 2361s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.86      0.93      0.89      4953
#     Positive       0.93      0.85      0.89      5047
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
#
# Terminando processo de: ep3 Social
#
# ep3 Fotografia
# 313/313 [==============================] - 2349s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.90      0.92      5042
#     Positive       0.90      0.93      0.92      4958
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2351s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.89      0.91      5042
#     Positive       0.89      0.94      0.92      4958
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.91     10000
# weighted avg       0.92      0.92      0.91     10000
#
# Terminando processo de: ep3 Fotografia
#
# ep3 Compras
# 313/313 [==============================] - 2364s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.96      0.96      4990
#     Positive       0.96      0.96      0.96      5010
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# 313/313 [==============================] - 2369s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.96      0.96      4990
#     Positive       0.96      0.96      0.96      5010
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# Terminando processo de: ep3 Compras
#
# ep3 Produtividade
# 313/313 [==============================] - 2370s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.90      0.92      5019
#     Positive       0.90      0.94      0.92      4981
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2343s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.86      0.91      5019
#     Positive       0.87      0.97      0.92      4981
#
#     accuracy                           0.91     10000
#    macro avg       0.92      0.91      0.91     10000
# weighted avg       0.92      0.91      0.91     10000
#
# Terminando processo de: ep3 Produtividade
#
# ep3 Educação
# 313/313 [==============================] - 2371s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.89      0.91      4933
#     Positive       0.90      0.94      0.92      5067
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2369s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.87      0.91      4933
#     Positive       0.89      0.95      0.92      5067
#
#     accuracy                           0.91     10000
#    macro avg       0.92      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000
#
# Terminando processo de: ep3 Educação
#
# ep3 Livros e Referência
# 313/313 [==============================] - 2359s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.89      0.90      5021
#     Positive       0.89      0.91      0.90      4979
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
# 313/313 [==============================] - 2385s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.87      0.89      5021
#     Positive       0.88      0.92      0.90      4979
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
# Terminando processo de: ep3 Livros e Referência
#
# ep3 Encontro
# 313/313 [==============================] - 2349s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.90      0.91      4986
#     Positive       0.90      0.93      0.92      5014
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2411s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.91      0.91      4986
#     Positive       0.91      0.92      0.92      5014
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.91      0.91     10000
# weighted avg       0.92      0.92      0.91     10000
#
# Terminando processo de: ep3 Encontro
#
# ep3 Clima
# 154/154 [==============================] - 1178s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.90      0.93      2467
#     Positive       0.91      0.96      0.93      2459
#
#     accuracy                           0.93      4926
#    macro avg       0.93      0.93      0.93      4926
# weighted avg       0.93      0.93      0.93      4926
#
# 154/154 [==============================] - 1170s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.97      0.88      0.92      2467
#     Positive       0.89      0.97      0.93      2459
#
#     accuracy                           0.93      4926
#    macro avg       0.93      0.93      0.93      4926
# weighted avg       0.93      0.93      0.93      4926
#
# Terminando processo de: ep3 Clima
#
# ep3 Turismo e Local
# 313/313 [==============================] - 2384s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.90      0.92      4953
#     Positive       0.91      0.93      0.92      5047
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2386s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.89      0.91      4953
#     Positive       0.90      0.94      0.92      5047
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# Terminando processo de: ep3 Turismo e Local
# ep3 Notícias e Revistas
# 123/123 [==============================] - 933s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.88      0.90      1965
#     Positive       0.88      0.93      0.90      1965
#
#     accuracy                           0.90      3930
#    macro avg       0.90      0.90      0.90      3930
# weighted avg       0.90      0.90      0.90      3930
#
# 123/123 [==============================] - 937s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.83      0.89      1965
#     Positive       0.85      0.96      0.90      1965
#
#     accuracy                           0.89      3930
#    macro avg       0.90      0.89      0.89      3930
# weighted avg       0.90      0.89      0.89      3930
#
# Terminando processo de: ep3 Notícias e Revistas
#
# ep3 Saúde
# 82/82 [==============================] - 619s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.79      0.84      1308
#     Positive       0.81      0.92      0.86      1308
#
#     accuracy                           0.85      2616
#    macro avg       0.86      0.85      0.85      2616
# weighted avg       0.86      0.85      0.85      2616
#
# 82/82 [==============================] - 623s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.73      0.82      1308
#     Positive       0.78      0.96      0.86      1308
#
#     accuracy                           0.84      2616
#    macro avg       0.86      0.84      0.84      2616
# weighted avg       0.86      0.84      0.84      2616
#
# Terminando processo de: ep3 Saúde
#
# ep3 Personalização
# 227/227 [==============================] - 1729s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.86      0.90      3625
#     Positive       0.87      0.95      0.91      3622
#
#     accuracy                           0.90      7247
#    macro avg       0.91      0.90      0.90      7247
# weighted avg       0.91      0.90      0.90      7247
#
# 227/227 [==============================] - 1733s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.82      0.88      3625
#     Positive       0.84      0.97      0.90      3622
#
#     accuracy                           0.89      7247
#    macro avg       0.90      0.89      0.89      7247
# weighted avg       0.90      0.89      0.89      7247
#
# Terminando processo de: ep3 Personalização
#
# ep3 Ferramentas
# 313/313 [==============================] - 2374s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.88      0.90      5054
#     Positive       0.88      0.92      0.90      4946
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
# 313/313 [==============================] - 2374s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.88      0.90      5054
#     Positive       0.88      0.92      0.90      4946
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
# Terminando processo de: ep3 Ferramentas
#
# ep3 Casa
# 169/169 [==============================] - 1274s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.96      0.95      2695
#     Positive       0.96      0.95      0.95      2691
#
#     accuracy                           0.95      5386
#    macro avg       0.95      0.95      0.95      5386
# weighted avg       0.95      0.95      0.95      5386
#
# 169/169 [==============================] - 1273s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.96      0.95      2695
#     Positive       0.96      0.95      0.95      2691
#
#     accuracy                           0.95      5386
#    macro avg       0.95      0.95      0.95      5386
# weighted avg       0.95      0.95      0.95      5386
#
# Terminando processo de: ep3 Casa
#
# ep3 Veículo
# 238/238 [==============================] - 1804s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.94      0.94      3800
#     Positive       0.94      0.94      0.94      3798
#
#     accuracy                           0.94      7598
#    macro avg       0.94      0.94      0.94      7598
# weighted avg       0.94      0.94      0.94      7598
#
# 238/238 [==============================] - 1813s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.93      0.94      3800
#     Positive       0.93      0.95      0.94      3798
#
#     accuracy                           0.94      7598
#    macro avg       0.94      0.94      0.94      7598
# weighted avg       0.94      0.94      0.94      7598
#
# Terminando processo de: ep3 Veículo
#
# ep3 Esportes
# 41/41 [==============================] - 305s 7s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.96      0.94       644
#     Positive       0.96      0.91      0.93       641
#
#     accuracy                           0.94      1285
#    macro avg       0.94      0.94      0.94      1285
# weighted avg       0.94      0.94      0.94      1285
#
# 41/41 [==============================] - 280s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.97      0.93       644
#     Positive       0.96      0.89      0.93       641
#
#     accuracy                           0.93      1285
#    macro avg       0.93      0.93      0.93      1285
# weighted avg       0.93      0.93      0.93      1285
#
# Terminando processo de: ep3 Esportes
#
# ep3 Arte e Design
# 313/313 [==============================] - 2357s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.91      0.92      5011
#     Positive       0.91      0.93      0.92      4989
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 2394s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.89      0.92      5011
#     Positive       0.89      0.95      0.92      4989
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# Terminando processo de: ep3 Arte e Design
#
# ep3 Biblioteca
# 41/41 [==============================] - 314s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.88      0.88       641
#     Positive       0.88      0.88      0.88       641
#
#     accuracy                           0.88      1282
#    macro avg       0.88      0.88      0.88      1282
# weighted avg       0.88      0.88      0.88      1282
#
# 41/41 [==============================] - 304s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.89      0.88       641
#     Positive       0.89      0.88      0.88       641
#
#     accuracy                           0.88      1282
#    macro avg       0.88      0.88      0.88      1282
# weighted avg       0.88      0.88      0.88      1282
#
# Terminando processo de: ep3 Biblioteca
#
# ep3 Criar os Filhos
# 24/24 [==============================] - 182s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.90      0.91       384
#     Positive       0.90      0.91      0.91       384
#
#     accuracy                           0.91       768
#    macro avg       0.91      0.91      0.91       768
# weighted avg       0.91      0.91      0.91       768
# 24/24 [==============================] - 182s 8s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.92      0.92       384
#     Positive       0.92      0.91      0.92       384
#
#     accuracy                           0.92       768
#    macro avg       0.92      0.92      0.92       768
# weighted avg       0.92      0.92      0.92       768
#
# Terminando processo de: ep3 Criar os Filhos
#
# ep3 Eventos
# 17/17 [==============================] - 123s 7s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.98      0.95       260
#     Positive       0.98      0.91      0.94       260
#
#     accuracy                           0.94       520
#    macro avg       0.95      0.94      0.94       520
# weighted avg       0.95      0.94      0.94       520
#
# 17/17 [==============================] - 114s 7s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.98      0.94       260
#     Positive       0.98      0.90      0.94       260
#
#     accuracy                           0.94       520
#    macro avg       0.94      0.94      0.94       520
# weighted avg       0.94      0.94      0.94       520
#
# Terminando processo de: ep3 Eventos
#
# ep3 Humor
# 22/22 [==============================] - 167s 8s/step
# Métricas com contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.86      0.84      0.85       347
#     Positive       0.85      0.86      0.86       348
#
#     accuracy                           0.85       695
#    macro avg       0.85      0.85      0.85       695
# weighted avg       0.85      0.85      0.85       695
#
# 22/22 [==============================] - 104s 5s/step
# Métricas sem contexto:
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.84      0.85       347
#     Positive       0.84      0.85      0.85       348
#
#     accuracy                           0.85       695
#    macro avg       0.85      0.85      0.85       695
# weighted avg       0.85      0.85      0.85       695
#
# Terminando processo de: ep3 Humor
#
# Encerrada a execução ----------------------------------------------------------

# %%
print(NAME_TERMINAL)
for i in range(len(save_classification_context)):
    print('context -', CATEGORIES_LIST[i])
    print(save_classification_context[i])
    print('non context -', CATEGORIES_LIST[i])
    print(save_classification_non_context[i])
# Out:
# [[0.8209061  0.17909394]
#  [0.11296224 0.88703775]
#  [0.00424123 0.9957587 ]
#  ...
#  [0.06993139 0.9300686 ]
#  [0.02282292 0.9771771 ]
#  [0.93798983 0.06201014]]
